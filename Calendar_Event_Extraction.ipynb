# %% [markdown]
# # Google Calendar Event Fetcher
#
# #### The Notebook demonstrates how to programmatically retrieve and process Google Calendar events for a given user and date range.
#
# ##### Key Steps:
#
# Authentication: Load user credentials from a token file.
#
# API Call: Fetch events between specified start/end dates using the Google Calendar API.
#
# Data Processing: Extract event details (start/end times, attendees) and structure them into a clean format.
#
# Output: Return a list of events with attendee counts and time slots.
# ```

# %% [markdown]
# ### Importing Required Libraries

# %%
import json
from datetime import datetime, timezone, timedelta
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build

# %% [markdown]
# ### Defining the retrive_calendar_events Function that includes :
# #### 1. Authenticating with Google Calendar
# #### 2. Fetching Events
# #### 3. Processing Events & Structuring

# %%
def retrive_calendar_events(user, start, end):
    events_list = []
    token_path = "Keys/"+user.split("@")[0]+".token"
    user_creds = Credentials.from_authorized_user_file(token_path)
    calendar_service = build("calendar", "v3", credentials=user_creds)
    events_result = calendar_service.events().list(calendarId='primary', timeMin=start,timeMax=end,singleEvents=True,orderBy='startTime').execute()
    events = events_result.get('items')
    
    for event in events : 
        attendee_list = []
        try:
            for attendee in event["attendees"]: 
                attendee_list.append(attendee['email'])
        except: 
            attendee_list.append("SELF")
        start_time = event["start"]["dateTime"]
        end_time = event["end"]["dateTime"]
        events_list.append(
            {"StartTime" : start_time, 
             "EndTime": end_time, 
             "NumAttendees" :len(set(attendee_list)), 
             "Attendees" : list(set(attendee_list)),
             "Summary" : event["summary"]})
    return events_list

# %%
def retrive_calendar_events(user, start, end):
    events_list = []
    token_path = "Keys/"+user.split("@")[0]+".token"
    user_creds = Credentials.from_authorized_user_file(token_path)
    calendar_service = build("calendar", "v3", credentials=user_creds)
    events_result = calendar_service.events().list(calendarId='primary', timeMin=start,timeMax=end,singleEvents=True,orderBy='startTime').execute()
    events = events_result.get('items')
    
    for event in events : 
        attendee_list = []
        try:
            for attendee in event["attendees"]: 
                attendee_list.append(attendee['email'])
        except: 
            attendee_list.append("SELF")
        
        # Handle both timed events and all-day events
        if "dateTime" in event["start"]:
            start_time = event["start"]["dateTime"]
            end_time = event["end"]["dateTime"]
        else:
            # All-day event - use date instead
            start_time = event["start"]["date"]
            end_time = event["end"]["date"]
        
        events_list.append(
            {"StartTime" : start_time, 
             "EndTime": end_time, 
             "NumAttendees" :len(set(attendee_list)), 
             "Attendees" : list(set(attendee_list)),
             "Summary" : event["summary"]})
    return events_list

# %% [markdown]
# ### Calling ```retrive_calendar_events``` with Auth Token, Start Date & End Date
# #### Date Format : YYYY-MM-DD (T) HH:MM:SS +TIMEZONE (+5:30 Indicates IST Time Zone Asia/Kolkata )

# %%
event = retrive_calendar_events("userthree.amd@gmail.com", '2025-07-01T00:00:00+05:30', '2025-07-30T23:59:59+05:30')

# %% [markdown]
# ### Output that describing sample event :

# %%
event
# Out:
# [{'StartTime': '2025-06-30T16:00:00+05:30',
#   'EndTime': '2025-07-01T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-01T16:00:00+05:30',
#   'EndTime': '2025-07-02T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-02T16:00:00+05:30',
#   'EndTime': '2025-07-03T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-03T16:00:00+05:30',
#   'EndTime': '2025-07-04T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-04T16:00:00+05:30',
#   'EndTime': '2025-07-05T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-05',
#   'EndTime': '2025-07-06',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-05T16:00:00+05:30',
#   'EndTime': '2025-07-06T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-06',
#   'EndTime': '2025-07-07',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-06T16:00:00+05:30',
#   'EndTime': '2025-07-07T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-07T16:00:00+05:30',
#   'EndTime': '2025-07-08T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-08T16:00:00+05:30',
#   'EndTime': '2025-07-09T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-09T16:00:00+05:30',
#   'EndTime': '2025-07-10T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-10T16:00:00+05:30',
#   'EndTime': '2025-07-11T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-11T09:00:00+05:30',
#   'EndTime': '2025-07-11T17:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Workshop Advance AI'},
#  {'StartTime': '2025-07-11T16:00:00+05:30',
#   'EndTime': '2025-07-12T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-12',
#   'EndTime': '2025-07-13',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-12T16:00:00+05:30',
#   'EndTime': '2025-07-13T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-13',
#   'EndTime': '2025-07-14',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-13T16:00:00+05:30',
#   'EndTime': '2025-07-14T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-14T09:00:00+05:30',
#   'EndTime': '2025-07-14T10:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': '1V1 Team Member'},
#  {'StartTime': '2025-07-14T14:00:00+05:30',
#   'EndTime': '2025-07-14T15:00:00+05:30',
#   'NumAttendees': 3,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Team Meet'},
#  {'StartTime': '2025-07-14T16:00:00+05:30',
#   'EndTime': '2025-07-15T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-15T09:00:00+05:30',
#   'EndTime': '2025-07-15T16:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'AMD AI Workshop'},
#  {'StartTime': '2025-07-15T16:00:00+05:30',
#   'EndTime': '2025-07-16T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-16T10:00:00+05:30',
#   'EndTime': '2025-07-16T11:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Customer Call - Quarterly update'},
#  {'StartTime': '2025-07-16T16:00:00+05:30',
#   'EndTime': '2025-07-17T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-17T16:00:00+05:30',
#   'EndTime': '2025-07-18T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-18T09:00:00+05:30',
#   'EndTime': '2025-07-18T17:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Workshop Advance AI'},
#  {'StartTime': '2025-07-18T16:00:00+05:30',
#   'EndTime': '2025-07-19T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-19',
#   'EndTime': '2025-07-20',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-19T16:00:00+05:30',
#   'EndTime': '2025-07-20T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-20',
#   'EndTime': '2025-07-21',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-20',
#   'EndTime': '2025-07-21',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-20T07:45:00+05:30',
#   'EndTime': '2025-07-20T08:15:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T08:30:00+05:30',
#   'EndTime': '2025-07-20T09:00:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T09:15:00+05:30',
#   'EndTime': '2025-07-20T09:45:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T10:00:00+05:30',
#   'EndTime': '2025-07-20T10:30:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T10:45:00+05:30',
#   'EndTime': '2025-07-20T11:15:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T11:30:00+05:30',
#   'EndTime': '2025-07-20T12:00:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T12:15:00+05:30',
#   'EndTime': '2025-07-20T12:45:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-20T16:00:00+05:30',
#   'EndTime': '2025-07-21T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-21T07:30:00+05:30',
#   'EndTime': '2025-07-21T08:00:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Client Validation - Urgent'},
#  {'StartTime': '2025-07-21T09:00:00+05:30',
#   'EndTime': '2025-07-21T10:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': '1v1 with Team Member'},
#  {'StartTime': '2025-07-21T10:00:00+05:30',
#   'EndTime': '2025-07-21T10:30:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-21T10:30:00+05:30',
#   'EndTime': '2025-07-21T11:00:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Agentic AI Project Status Update'},
#  {'StartTime': '2025-07-21T16:00:00+05:30',
#   'EndTime': '2025-07-22T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-22T07:30:00+05:30',
#   'EndTime': '2025-07-22T08:30:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Project Status'},
#  {'StartTime': '2025-07-22T09:00:00+05:30',
#   'EndTime': '2025-07-22T17:00:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Workshop - AI Agents'},
#  {'StartTime': '2025-07-22T16:00:00+05:30',
#   'EndTime': '2025-07-23T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-23T07:30:00+05:30',
#   'EndTime': '2025-07-23T08:00:00+05:30',
#   'NumAttendees': 4,
#   'Attendees': ['usertwo.amd@gmail.com',
#    'team@amd.com',
#    'userthree.amd@gmail.com',
#    'userone.amd@gmail.com'],
#   'Summary': 'Client Feedback'},
#  {'StartTime': '2025-07-23T16:00:00+05:30',
#   'EndTime': '2025-07-24T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-24T16:00:00+05:30',
#   'EndTime': '2025-07-25T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-25T16:00:00+05:30',
#   'EndTime': '2025-07-26T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-26',
#   'EndTime': '2025-07-27',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-26T16:00:00+05:30',
#   'EndTime': '2025-07-27T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-27',
#   'EndTime': '2025-07-28',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-27',
#   'EndTime': '2025-07-28',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Weekend'},
#  {'StartTime': '2025-07-27T16:00:00+05:30',
#   'EndTime': '2025-07-28T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-28T16:00:00+05:30',
#   'EndTime': '2025-07-29T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-29T16:00:00+05:30',
#   'EndTime': '2025-07-30T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'},
#  {'StartTime': '2025-07-30T16:00:00+05:30',
#   'EndTime': '2025-07-31T07:30:00+05:30',
#   'NumAttendees': 1,
#   'Attendees': ['SELF'],
#   'Summary': 'Off Hours'}]
